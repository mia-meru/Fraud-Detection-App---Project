# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")

# %%
df=pd.read_csv("AIML Dataset.csv")

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
(df["isFraud"].value_counts()[1]/df.shape[0])*100
# Out:
# np.float64(0.12908204481801522)

# %%
df["type"].value_counts().plot(kind="bar", title= "transaction types",color=["purple","skyblue"])
plt.xlabel("transaction type")
plt.ylabel("count")
plt.show()

# %%
fraud_by_type=df.groupby("type")["isFraud"].mean().sort_values(ascending=False)
fraud_by_type.plot(kind="bar", title="fraud by type",color=["red"])
plt.ylabel("fraud rate")
plt.show()

# %%
df["amount"].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
sns.histplot(np.log1p(df["amount"]), bins=100,kde=True,color="salmon")
plt.title("Transaction Amount Distribution")
plt.xlabel("log(Amount+1)")
plt.show()

# %%
sns.boxplot(data=df[df["amount"]<40000],x="isFraud",y="amount",palette=["blue"])
plt.title("amount by fraud")
plt.show()

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df["balanceDiffOrig"]=df["oldbalanceOrg"]-df["newbalanceOrig"]
df["balanceDiffDest"]=df["newbalanceDest"]-df["oldbalanceDest"]

# %%
(df["balanceDiffOrig"]<0).sum()
# Out:
# np.int64(1399253)

# %%
(df["balanceDiffDest"]<0).sum()
# Out:
# np.int64(1238864)

# %%
df.head(3)
# Out:
#    step      type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT  9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT  1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER   181.00  C1305486145          181.0            0.00
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
#
#    balanceDiffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0
# 2           181.00              0.0

# %%
frauds_per_step=df[df["isFraud"]==1]["step"].value_counts().sort_index()
plt.plot(frauds_per_step.index,frauds_per_step.values, label="Frauds per Step")
plt.xlabel("Step(Time)")
plt.ylabel("number of frauds")
plt.title("Frauds over time")
plt.grid(True)
plt.show()

# %%
df.drop(columns='step',inplace=True)

# %%
top_senders= df["nameOrig"].value_counts().head(10)
top_receivers=df["nameDest"].value_counts().head(10)

# %%
fraud_users=df[df["isFraud"]==1]["nameOrig"].value_counts().head(10)

# %%
fraud_types=df[df["type"].isin(["TRANSFER","CASH_OUT"])]

# %%
fraud_types["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
corr=df[["amount","oldbalanceOrg","oldbalanceDest","newbalanceOrig","newbalanceDest","isFraud"]].corr()

# %%
corr
# Out:
#                   amount  oldbalanceOrg  oldbalanceDest  newbalanceOrig  \
# amount          1.000000      -0.002762        0.294137       -0.007861
# oldbalanceOrg  -0.002762       1.000000        0.066243        0.998803
# oldbalanceDest  0.294137       0.066243        1.000000        0.067812
# newbalanceOrig -0.007861       0.998803        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.976569        0.041837
# isFraud         0.076688       0.010154       -0.005885       -0.008148
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# oldbalanceDest        0.976569 -0.005885
# newbalanceOrig        0.041837 -0.008148
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr,annot=True,cmap="coolwarm",fmt=".2f")
plt.title("correlation matrix")
plt.show()

# %%
zero_after_transfer=df[
    (df["oldbalanceOrg"]>0)&
    (df["newbalanceOrig"]==0)&
    (df["type"].isin(["TRANSFER","CASH_OUT"]))
]

# %%
zero_after_transfer.head()
# Out:
#         type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2   TRANSFER     181.00  C1305486145          181.0             0.0
# 3   CASH_OUT     181.00   C840083671          181.0             0.0
# 15  CASH_OUT  229133.94   C905080434        15325.0             0.0
# 19  TRANSFER  215310.30  C1670993182          705.0             0.0
# 24  TRANSFER  311685.89  C1984094095        10835.0             0.0
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2    C553264065             0.0            0.00        1               0
# 3     C38997010         21182.0            0.00        1               0
# 15   C476402209          5083.0        51513.44        0               0
# 19  C1100439041         22425.0            0.00        0               0
# 24   C932583850          6267.0      2719172.89        0               0
#
#     balanceDiffOrig  balanceDiffDest
# 2             181.0             0.00
# 3             181.0        -21182.00
# ...

# %% [markdown]
# # Feature engineering

# %%
#We have an imbalance situation for the fraud value count, we will use feature selection and preparation

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression   
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from imblearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df_model=df.drop(["nameOrig","nameDest","isFlaggedFraud"], axis=1)

# %%
df_model.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  balanceDiffOrig  balanceDiffDest
# 0             0.0        0          9839.64              0.0
# 1             0.0        0          1864.28              0.0
# 2             0.0        1           181.00              0.0
# 3             0.0        1           181.00         -21182.0
# 4             0.0        0         11668.14              0.0

# %%
categorical=["type"]
numerical=["amount","oldbalanceOrg","newbalanceOrig","oldbalanceDest","newbalanceDest","balanceDiffOrig","balanceDiffDest"]

# %%
y=df_model["isFraud"]
x=df_model.drop("isFraud",axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,stratify=y,random_state=0)

# %%
preprocessor= ColumnTransformer(
    transformers= [
        ("num",StandardScaler(),numerical),
        ("cat",OneHotEncoder(drop="first"),categorical)
    ],
    remainder="drop"
)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(sampling_strategy='minority', random_state=42)

# %%
my_pipeline=Pipeline([
    ("prep",preprocessor),
    ("smote", smote),
    ("clf",LogisticRegression( max_iter=1000))
])

# %%
my_pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest',
#                                                    'balanceDiffOrig',
#                                                    'balanceDiffDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('smote', SMOTE(random_state=42, sampling_strategy='minority')),
#                 ('clf', LogisticRegression(max_iter=1000))])

# %%
y_pred=my_pipeline.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1906322
#            1       0.02      0.94      0.05      2464
#
#     accuracy                           0.95   1908786
#    macro avg       0.51      0.95      0.51   1908786
# weighted avg       1.00      0.95      0.97   1908786

# %%
my_pipeline.score(x_test,y_test)
# Out:
# 0.9489748981813572

# %%
y_pred_percentage = my_pipeline.predict_proba(x_test)

# %% [markdown]
# # Result comparison
#
#
# I tried different way to handle the imbalance situation but it didn't changed much, here is a comparison of
# - Results before using SMOTE
#
#
# ![Results before using SMOTE](<Without SMOTE.PNG>)
#
#
# - Results after using SMOTE
#
#
# ![Results after using SMOTE ](<With SMOTE.PNG>)

# %%
X_processed = preprocessor.fit_transform(x_train)
X_res, y_res = SMOTE(random_state=42).fit_resample(X_processed, y_train)
plt.bar(y_res.value_counts().index, y_res.value_counts().values, 
        color=['skyblue','salmon'])
plt.xticks([0,1], ['Non-Fraud', 'Fraud'])
plt.ylabel("Count")
plt.title("Class Distribution AFTER SMOTE")
plt.show()

# %%
import joblib

joblib.dump(my_pipeline,"fraud_detection_pipeline.pkl")
# Out:
# ['fraud_detection_pipeline.pkl']
